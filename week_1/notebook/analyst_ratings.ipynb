# %%
import pandas as pd
let_me_cook=pd.read_csv("/content/raw_analyst_ratings.csv")
let_me_cook.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock
# 0  2020-06-05 10:30:54-04:00     A
# 1  2020-06-03 10:45:20-04:00     A
# 2  2020-05-26 04:30:07-04:00     A
# 3  2020-05-22 12:45:06-04:00     A
# 4  2020-05-22 11:38:59-04:00     A

# %%
let_me_cook['head_line_len']=len(let_me_cook['headline'])

# %%
let_me_cook.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock  head_line_len
# 0  2020-06-05 10:30:54-04:00     A          31773
# 1  2020-06-03 10:45:20-04:00     A          31773
# 2  2020-05-26 04:30:07-04:00     A          31773
# 3  2020-05-22 12:45:06-04:00     A          31773
# 4  2020-05-22 11:38:59-04:00     A          31773

# %%
head_len_mean=let_me_cook['head_line_len'].mean()

# %%
head_len_mean
# Out:
# 31773.0

# %%
head_len_median=let_me_cook['head_line_len'].median()

# %%
head_len_median
# Out:
# 31773.0

# %%
head_len_std=let_me_cook['head_line_len'].std()

# %%
head_len_std
# Out:
# 0.0

# %%
let_me_cook["publisher"].value_counts()
# Out:
# publisher
# Paul Quintaro         5103
# Lisa Levin            4614
# Benzinga Newsdesk     3462
# Monica Gerson         1998
# Charles Gross         1926
#                       ...
# Marcus Goncalves         1
# David Tumm               1
# Wall Street Mess         1
# Phil's Stock World       1
# Invest 2 Success         1
# Name: count, Length: 388, dtype: int64

# %%
#from the above who wrote the most headlines
let_me_cook.groupby("publisher")["head_line_len"].mean()
# Out:
# publisher
# Abe Raymond                  31773.0
# Abhi Rao                     31773.0
# Above Average Odds           31773.0
# Activist Stocks              31773.0
# Adam Sarhan                  31773.0
#                               ...
# tradermark                   31773.0
# vishwanath@benzinga.com      31773.0
# vivek.proactive@gmail.com    31773.0
# wallstreet1928               31773.0
# webmaster                    31773.0
# Name: head_line_len, Length: 388, dtype: float64

# %%
let_me_cook.groupby("publisher").head()
# Out:
#        Unnamed: 0                                           headline  \
# 0               0            Stocks That Hit 52-Week Highs On Friday
# 1               1         Stocks That Hit 52-Week Highs On Wednesday
# 2               2                      71 Biggest Movers From Friday
# 3               3       46 Stocks Moving In Friday's Mid-Day Session
# 4               4  B of A Securities Maintains Neutral on Agilent...
# ...           ...                                                ...
# 30983       31523  Advaxis Reports Q4 EPS $(2.31) vs. $(2.08) In ...
# 31256       31797  Investor Tools for Trading Oil and Gas Stocks ...
# 31524       32065  UPDATE: Morgan Stanley Raises PT on Ameren Cor...
# 31667       32208                    Ameren Beats Expectations (AEE)
# 31669       32210                                  Premarket Roundup
#
#                                                      url          publisher  \
# 0      https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1      https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2      https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3      https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4      https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
# ...                                                  ...                ...
# 30983  https://www.benzinga.com/news/earnings/17/12/1...  Christina Jackson
# 31256  https://www.benzinga.com/markets/11/02/828660/...      InvestorIdeas
# 31524  https://www.benzinga.com/analyst-ratings/analy...    Frank Sylvester
# 31667  https://www.benzinga.com/markets/company-news/...         chenry4287
# 31669  https://www.benzinga.com/general/131655/premar...         chenry4287
#
#                             date stock  head_line_len
# 0      2020-06-05 10:30:54-04:00     A          31773
# 1      2020-06-03 10:45:20-04:00     A          31773
# 2      2020-05-26 04:30:07-04:00     A          31773
# 3      2020-05-22 12:45:06-04:00     A          31773
# 4      2020-05-22 11:38:59-04:00     A          31773
# ...                          ...   ...            ...
# 30983        2017-12-20 00:00:00  ADXS          31773
# 31256        2011-02-02 00:00:00    AE          31773
# 31524        2013-03-15 00:00:00   AEE          31773
# 31667        2010-02-18 00:00:00   AEE          31773
# 31669        2010-02-18 00:00:00   AEE          31773
#
# [1284 rows x 7 columns]

# %%
publisher_per_article=let_me_cook.groupby("publisher")['headline'].count()

# %%
#here is the most active publishers
sorted_publisher_with_article=publisher_per_article.sort_values(ascending=False)
sorted_publisher_with_article
# Out:
# publisher
# Paul Quintaro        5103
# Lisa Levin           4614
# Benzinga Newsdesk    3462
# Monica Gerson        1998
# Charles Gross        1926
#                      ...
# Marketfy Insights       1
# Ari Crane               1
# Michael Kudrna          1
# Michael Snyder          1
# Katey Stapleton         1
# Name: headline, Length: 388, dtype: int64

# %%
let_me_cook["publication_date"]=pd.to_datetime(let_me_cook["date"],errors='coerce')

# %%
let_me_cook.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock  head_line_len          publication_date
# 0  2020-06-05 10:30:54-04:00     A          31773 2020-06-05 10:30:54-04:00
# 1  2020-06-03 10:45:20-04:00     A          31773 2020-06-03 10:45:20-04:00
# 2  2020-05-26 04:30:07-04:00     A          31773 2020-05-26 04:30:07-04:00
# 3  2020-05-22 12:45:06-04:00     A          31773 2020-05-22 12:45:06-04:00
# 4  2020-05-22 11:38:59-04:00     A          31773 2020-05-22 11:38:59-04:00

# %%
let_me_cook["year"]=let_me_cook["publication_date"].dt.year

# %%
let_me_cook["month"]=let_me_cook["publication_date"].dt.month
let_me_cook['day'] =let_me_cook["publication_date"].dt.day
let_me_cook['weekly']=let_me_cook["publication_date"].dt.day_name()
let_me_cook.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock  head_line_len          publication_date  \
# 0  2020-06-05 10:30:54-04:00     A          31773 2020-06-05 10:30:54-04:00
# 1  2020-06-03 10:45:20-04:00     A          31773 2020-06-03 10:45:20-04:00
# 2  2020-05-26 04:30:07-04:00     A          31773 2020-05-26 04:30:07-04:00
# 3  2020-05-22 12:45:06-04:00     A          31773 2020-05-22 12:45:06-04:00
# 4  2020-05-22 11:38:59-04:00     A          31773 2020-05-22 11:38:59-04:00
#
#      year  month   day     weekly
# 0  2020.0    6.0   5.0     Friday
# 1  2020.0    6.0   3.0  Wednesday
# 2  2020.0    5.0  26.0    Tuesday
# 3  2020.0    5.0  22.0     Friday
# 4  2020.0    5.0  22.0     Friday

# %%
daily_counts = let_me_cook.groupby('publication_date').size().reset_index(name='article_count')
daily_counts
# Out:
#              publication_date  article_count
# 0   2011-09-14 09:17:19-04:00              1
# 1   2012-01-13 08:15:26-04:00              1
# 2   2012-02-08 00:22:47-04:00              1
# 3   2012-02-09 18:02:36-04:00              1
# 4   2012-03-01 17:28:55-04:00              1
# ..                        ...            ...
# 940 2020-06-10 11:21:01-04:00              1
# 941 2020-06-10 11:33:26-04:00              1
# 942 2020-06-10 15:09:50-04:00              1
# 943 2020-06-10 15:13:10-04:00              1
# 944 2020-06-10 15:17:32-04:00              1
#
# [945 rows x 2 columns]

# %%
let_me_cook.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock  head_line_len          publication_date  \
# 0  2020-06-05 10:30:54-04:00     A          31773 2020-06-05 10:30:54-04:00
# 1  2020-06-03 10:45:20-04:00     A          31773 2020-06-03 10:45:20-04:00
# 2  2020-05-26 04:30:07-04:00     A          31773 2020-05-26 04:30:07-04:00
# 3  2020-05-22 12:45:06-04:00     A          31773 2020-05-22 12:45:06-04:00
# 4  2020-05-22 11:38:59-04:00     A          31773 2020-05-22 11:38:59-04:00
#
#      year  month   day     weekly
# 0  2020.0    6.0   5.0     Friday
# 1  2020.0    6.0   3.0  Wednesday
# 2  2020.0    5.0  26.0    Tuesday
# 3  2020.0    5.0  22.0     Friday
# 4  2020.0    5.0  22.0     Friday

# %%
let_me_cook['stock'].value_counts()
# Out:
# stock
# AA      2739
# ADBE    1999
# A       1433
# ACN     1323
# ADSK    1141
#         ...
# ADRA       2
# ADRD       1
# ACCU       1
# ADZ        1
# AEB        1
# Name: count, Length: 110, dtype: int64

# %%
for i in let_me_cook.columns:
  print(i)
# Out:
# Unnamed: 0
# headline
# url
# publisher
# date
# stock
# head_line_len
# publication_date
# year
# month
# day
# weekly

# %%
over_all_counts = let_me_cook.groupby('publication_date').size()
over_all_counts.plot(title='over all Publication Trends')
# Out:
# <Axes: title={'center': 'over all Publication Trends'}, xlabel='publication_date'>

# %%
over_all_counts
# Out:
# publication_date
# 2011-09-14 09:17:19-04:00    1
# 2012-01-13 08:15:26-04:00    1
# 2012-02-08 00:22:47-04:00    1
# 2012-02-09 18:02:36-04:00    1
# 2012-03-01 17:28:55-04:00    1
#                             ..
# 2020-06-10 11:21:01-04:00    1
# 2020-06-10 11:33:26-04:00    1
# 2020-06-10 15:09:50-04:00    1
# 2020-06-10 15:13:10-04:00    1
# 2020-06-10 15:17:32-04:00    1
# Length: 945, dtype: int64

# %%
#publication per year
yearly_over_all_counts = let_me_cook.groupby('year').size()
yearly_over_all_counts
yearly_over_all_counts.plot(title='over all Publication Trends')
# Out:
# <Axes: title={'center': 'over all Publication Trends'}, xlabel='year'>

# %%
#publication months in each year deeply
yearly_over_all_counts = let_me_cook.groupby(['year', 'month']).size()
yearly_over_all_counts
yearly_over_all_counts.plot(title='monthly all Publication Trends')
# Out:
# <Axes: title={'center': 'monthly all Publication Trends'}, xlabel='year,month'>

# %%
#publication months in each year weekly
yearly_over_all_counts = let_me_cook.groupby(['year', 'month', 'weekly']).size()
yearly_over_all_counts
# Out:
# year    month  weekly
# 2011.0  9.0    Wednesday     1
# 2012.0  1.0    Friday        1
#         2.0    Thursday      1
#                Wednesday     1
#         3.0    Thursday      1
#                             ..
# 2020.0  6.0    Monday       37
#                Sunday        1
#                Thursday     15
#                Tuesday      19
#                Wednesday    39
# Length: 239, dtype: int64

# %%
yearly_over_all_counts.plot(title='weekly all Publication Trends')
# Out:
# <Axes: title={'center': 'weekly all Publication Trends'}, xlabel='year,month,weekly'>

# %%
#sentiment analysis
from textblob import TextBlob
def show_sentiment(text):
    blob= TextBlob(text)
    sentiment_score = blob.sentiment.polarity
    if sentiment_score > 0:
        return 'positive'
    elif sentiment_score < 0:
        return 'negative'
    else:
        return 'neutral'
let_me_cook['sentiment'] = let_me_cook['headline'].apply(show_sentiment)
let_me_cook.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock  head_line_len          publication_date  \
# 0  2020-06-05 10:30:54-04:00     A          31773 2020-06-05 10:30:54-04:00
# 1  2020-06-03 10:45:20-04:00     A          31773 2020-06-03 10:45:20-04:00
# 2  2020-05-26 04:30:07-04:00     A          31773 2020-05-26 04:30:07-04:00
# 3  2020-05-22 12:45:06-04:00     A          31773 2020-05-22 12:45:06-04:00
# 4  2020-05-22 11:38:59-04:00     A          31773 2020-05-22 11:38:59-04:00
#
#      year  month   day     weekly sentiment
# 0  2020.0    6.0   5.0     Friday   neutral
# 1  2020.0    6.0   3.0  Wednesday   neutral
# 2  2020.0    5.0  26.0    Tuesday   neutral
# 3  2020.0    5.0  22.0     Friday   neutral
# 4  2020.0    5.0  22.0     Friday   neutral

# %%
setminet='positive'
setminet2='negative'
setminet3='neutral'
let_me_cook['sentiment'].str.contains(setminet).sum()
# Out:
# 7197

# %%
let_me_cook['sentiment'].str.contains(setminet2).sum()
# Out:
# 2734

# %%
let_me_cook['sentiment'].str.contains(setminet3).sum()
# Out:
# 21842

# %%
let_me_cook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31773 entries, 0 to 31772
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        31773 non-null  int64
#  1   headline          31773 non-null  object
#  2   url               31773 non-null  object
#  3   publisher         31773 non-null  object
#  4   date              31773 non-null  object
#  5   stock             31772 non-null  object
#  6   head_line_len     31773 non-null  int64
#  7   publication_date  1022 non-null   datetime64[ns, UTC-04:00]
#  8   year              1022 non-null   float64
#  9   month             1022 non-null   float64
#  10  day               1022 non-null   float64
#  11  weekly            1022 non-null   object
#  12  sentiment         31773 non-null  object
# dtypes: datetime64[ns, UTC-04:00](1), float64(3), int64(2), object(7)
# memory usage: 3.2+ MB

# %%
let_me_cook.shape
# Out:
# (31773, 13)

# %%
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import spacy
load_spacy_english_model=spacy.load('en_core_web_sm')

#let remove stop words using funciton like is was has have
def text_preprocess(text):
  data=load_spacy_english_model(text)
  return [token.lemma_.lower() for token in data if not token.is_stop and not token.is_punct]
let_me_cook['preprocessed_headline'] = let_me_cook['headline'].apply(text_preprocess)
let_me_cook.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock  head_line_len          publication_date  \
# 0  2020-06-05 10:30:54-04:00     A          31773 2020-06-05 10:30:54-04:00
# 1  2020-06-03 10:45:20-04:00     A          31773 2020-06-03 10:45:20-04:00
# 2  2020-05-26 04:30:07-04:00     A          31773 2020-05-26 04:30:07-04:00
# 3  2020-05-22 12:45:06-04:00     A          31773 2020-05-22 12:45:06-04:00
# 4  2020-05-22 11:38:59-04:00     A          31773 2020-05-22 11:38:59-04:00
#
#      year  month   day     weekly sentiment  \
# 0  2020.0    6.0   5.0     Friday   neutral
# 1  2020.0    6.0   3.0  Wednesday   neutral
# 2  2020.0    5.0  26.0    Tuesday   neutral
# 3  2020.0    5.0  22.0     Friday   neutral
# 4  2020.0    5.0  22.0     Friday   neutral
#
#                                preprocessed_headline
# 0              [stock, hit, 52, week, highs, friday]
# 1           [stock, hit, 52, week, highs, wednesday]
# 2                          [71, big, movers, friday]
# 3       [46, stock, move, friday, mid, day, session]
# 4  [b, securities, maintains, neutral, agilent, t...

# %%
non_stop='price'
let_me_cook['preprocessed_headline'].str.contains(non_stop).sum()
# Out:
# 0.0

# %%
all_words = [word for sublist in let_me_cook['preprocessed_headline'] for word in sublist]

# %%
word_freq = Counter(all_words)

# %%
for word, freq in word_freq.most_common(10):
    print(f"{word}: {freq}")
# Out:
# $: 15226
# stock: 4612
# m: 3793
# market: 3381
# vs: 3120
# est: 3078
# share: 2689
# eps: 2220
# reports: 2020
# update: 2012

# %%
def extract_entities(text):
    doc = load_spacy_english_model(text)
    return [ent.text for ent in doc.ents]
let_me_cook['entities'] = let_me_cook['headline'].apply(extract_entities)
all_entities = [entity for sublist in let_me_cook['entities'] for entity in sublist]
entity_freq = Counter(all_entities)
for entity, freq in entity_freq.most_common(10):
    print(f"{entity}: {freq}")
# Out:
# Benzinga: 1200
# 52-Week: 659
# Pre-Market Session: 594
# Raises PT: 559
# Friday: 518
# Thursday: 510
# US: 504
# Q2: 452
# Wednesday: 448
# Yesterday: 434
# Benzinga: 1200
# 52-Week: 659
# Pre-Market Session: 594
# Raises PT: 559
# Friday: 518
# Thursday: 510
# US: 504
# Q2: 452
# Wednesday: 448
# Yesterday: 434

# %%
for i in let_me_cook.columns:
  print(i)

# %%
import matplotlib.pyplot as plt
let_me_cook.set_index('publication_date', inplace=True)
let_me_cook.head()
daily_counts = let_me_cook.resample('D').size()
monthly_counts = let_me_cook.resample('M').size()
yearly_counts = let_me_cook.resample('Y').size()
plt.figure(figsize=(14, 7))
plt.subplot(3, 1, 1)
daily_counts.plot()
plt.title('Daily Publication Counts')
plt.xlabel('Date')
plt.ylabel('Number of Publications')
# Out:
# Text(0, 0.5, 'Number of Publications')

# %%
plt.subplot(3, 1, 2)
monthly_counts.plot()
plt.title('Monthly Publication Counts')
plt.xlabel('Date')
plt.ylabel('Number of Publications')
# Out:
# Text(0, 0.5, 'Number of Publications')

# %%
plt.subplot(3, 1, 3)
yearly_counts.plot()
plt.title('Yearly Publication Counts')
plt.xlabel('Date')
plt.ylabel('Number of Publications')
# Out:
# Text(0, 0.5, 'Number of Publications')

# %%
apple=

# %%
let_me_cook['publisher'].value_counts()
top_n = 10
top_publishers = publisher_counts.head(top_n)
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.barplot(x=top_publishers.index, y=top_publishers.values, palette='viridis')
plt.title(f'Top {top_n} Publishers by Number of Articles')
plt.xlabel('Publisher')
plt.ylabel('Number of Articles')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-54-92e17feb1b9f>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_publishers.index, y=top_publishers.values, palette='viridis')

# %%
plt.figure(figsize=(12, 8))
top_publishers.plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette('viridis', top_n))
plt.title('Distribution of Articles Among Top Publishers')
plt.ylabel('')
plt.show()

# %%
def extract_domain_names(email):
  return email.split('@')[-1]

# %%
let_me_cook['domain'] = let_me_cook['publisher'].apply(extract_domain_names)

# %%
let_me_cook.head()
# Out:
#                            Unnamed: 0  \
# publication_date
# 2020-06-05 10:30:54-04:00           0
# 2020-06-03 10:45:20-04:00           1
# 2020-05-26 04:30:07-04:00           2
# 2020-05-22 12:45:06-04:00           3
# 2020-05-22 11:38:59-04:00           4
#
#                                                                     headline  \
# publication_date
# 2020-06-05 10:30:54-04:00            Stocks That Hit 52-Week Highs On Friday
# 2020-06-03 10:45:20-04:00         Stocks That Hit 52-Week Highs On Wednesday
# 2020-05-26 04:30:07-04:00                      71 Biggest Movers From Friday
# 2020-05-22 12:45:06-04:00       46 Stocks Moving In Friday's Mid-Day Session
# 2020-05-22 11:38:59-04:00  B of A Securities Maintains Neutral on Agilent...
#
#                                                                          url  \
# publication_date
# 2020-06-05 10:30:54-04:00  https://www.benzinga.com/news/20/06/16190091/s...
# 2020-06-03 10:45:20-04:00  https://www.benzinga.com/news/20/06/16170189/s...
# 2020-05-26 04:30:07-04:00  https://www.benzinga.com/news/20/05/16103463/7...
# 2020-05-22 12:45:06-04:00  https://www.benzinga.com/news/20/05/16095921/4...
# 2020-05-22 11:38:59-04:00  https://www.benzinga.com/news/20/05/16095304/b...
#
#                                    publisher                       date stock  \
# publication_date
# 2020-06-05 10:30:54-04:00  Benzinga Insights  2020-06-05 10:30:54-04:00     A
# 2020-06-03 10:45:20-04:00  Benzinga Insights  2020-06-03 10:45:20-04:00     A
# 2020-05-26 04:30:07-04:00         Lisa Levin  2020-05-26 04:30:07-04:00     A
# 2020-05-22 12:45:06-04:00         Lisa Levin  2020-05-22 12:45:06-04:00     A
# 2020-05-22 11:38:59-04:00         Vick Meyer  2020-05-22 11:38:59-04:00     A
#
#                            head_line_len    year  month   day     weekly  \
# publication_date
# 2020-06-05 10:30:54-04:00          31773  2020.0    6.0   5.0     Friday
# 2020-06-03 10:45:20-04:00          31773  2020.0    6.0   3.0  Wednesday
# 2020-05-26 04:30:07-04:00          31773  2020.0    5.0  26.0    Tuesday
# 2020-05-22 12:45:06-04:00          31773  2020.0    5.0  22.0     Friday
# 2020-05-22 11:38:59-04:00          31773  2020.0    5.0  22.0     Friday
#
#                           sentiment  \
# publication_date
# 2020-06-05 10:30:54-04:00   neutral
# 2020-06-03 10:45:20-04:00   neutral
# 2020-05-26 04:30:07-04:00   neutral
# 2020-05-22 12:45:06-04:00   neutral
# 2020-05-22 11:38:59-04:00   neutral
#
#                                                        preprocessed_headline  \
# publication_date
# 2020-06-05 10:30:54-04:00              [stock, hit, 52, week, highs, friday]
# 2020-06-03 10:45:20-04:00           [stock, hit, 52, week, highs, wednesday]
# 2020-05-26 04:30:07-04:00                          [71, big, movers, friday]
# 2020-05-22 12:45:06-04:00       [46, stock, move, friday, mid, day, session]
# 2020-05-22 11:38:59-04:00  [b, securities, maintains, neutral, agilent, t...
#
#                                                 entities             domain
# publication_date
# 2020-06-05 10:30:54-04:00              [52-Week, Friday]  Benzinga Insights
# 2020-06-03 10:45:20-04:00           [52-Week, Wednesday]  Benzinga Insights
# 2020-05-26 04:30:07-04:00                   [71, Friday]         Lisa Levin
# 2020-05-22 12:45:06-04:00  [46, Friday, Mid-Day Session]         Lisa Levin
# 2020-05-22 11:38:59-04:00                           [88]         Vick Meyer

# %%
#TASK 2

# %%
apple=pd.read_csv("/content/AAPL_historical_data.csv")
amazon=pd.read_csv("/content/AMZN_historical_data.csv")
google=pd.read_csv("/content/GOOG_historical_data.csv")
microsoft=pd.read_csv("/content/MSFT_historical_data.csv")
meta=pd.read_csv("/content/META_historical_data.csv")
nevida=pd.read_csv("/content/NVDA_historical_data.csv")
tesla=pd.read_csv("/content/TSLA_historical_data.csv")

# %%
apple.info()
amazon.info()
google.info()
microsoft.info()
meta.info()
nevida.info()
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10998 entries, 0 to 10997
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          10998 non-null  object
#  1   Open          10998 non-null  float64
#  2   High          10998 non-null  float64
#  3   Low           10998 non-null  float64
#  4   Close         10998 non-null  float64
#  5   Adj Close     10998 non-null  float64
#  6   Volume        10998 non-null  int64
#  7   Dividends     10998 non-null  float64
#  8   Stock Splits  10998 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 773.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6846 entries, 0 to 6845
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          6846 non-null   object
#  1   Open          6846 non-null   float64
#  2   High          6846 non-null   float64
#  3   Low           6846 non-null   float64
#  4   Close         6846 non-null   float64
#  5   Adj Close     6846 non-null   float64
#  6   Volume        6846 non-null   int64
#  7   Dividends     6846 non-null   float64
#  8   Stock Splits  6846 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 481.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5020 entries, 0 to 5019
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5020 non-null   object
#  1   Open          5020 non-null   float64
#  2   High          5020 non-null   float64
#  3   Low           5020 non-null   float64
#  4   Close         5020 non-null   float64
#  5   Adj Close     5020 non-null   float64
#  6   Volume        5020 non-null   int64
#  7   Dividends     5020 non-null   float64
#  8   Stock Splits  5020 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 353.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9672 entries, 0 to 9671
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          9672 non-null   object
#  1   Open          9672 non-null   float64
#  2   High          9672 non-null   float64
#  3   Low           9672 non-null   float64
#  4   Close         9672 non-null   float64
#  5   Adj Close     9672 non-null   float64
#  6   Volume        9672 non-null   int64
#  7   Dividends     9672 non-null   float64
#  8   Stock Splits  9672 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 680.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2926 entries, 0 to 2925
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2926 non-null   object
#  1   Open          2926 non-null   float64
#  2   High          2926 non-null   float64
#  3   Low           2926 non-null   float64
#  4   Close         2926 non-null   float64
#  5   Adj Close     2926 non-null   float64
#  6   Volume        2926 non-null   int64
#  7   Dividends     2926 non-null   float64
#  8   Stock Splits  2926 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 205.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6421 entries, 0 to 6420
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          6421 non-null   object
#  1   Open          6421 non-null   float64
#  2   High          6421 non-null   float64
#  3   Low           6421 non-null   float64
#  4   Close         6421 non-null   float64
#  5   Adj Close     6421 non-null   float64
#  6   Volume        6421 non-null   int64
#  7   Dividends     6421 non-null   float64
#  8   Stock Splits  6421 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 451.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3545 entries, 0 to 3544
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          3545 non-null   object
#  1   Open          3545 non-null   float64
#  2   High          3545 non-null   float64
#  3   Low           3545 non-null   float64
#  4   Close         3545 non-null   float64
#  5   Adj Close     3545 non-null   float64
#  6   Volume        3545 non-null   int64
#  7   Dividends     3545 non-null   float64
#  8   Stock Splits  3545 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 249.4+ KB

# %%
apple.shape
# Out:
# (3545, 9)

# %%
amazon.shape
# Out:
# (3545, 9)

# %%
google.shape
# Out:
# (3545, 9)

# %%
microsoft.shape
# Out:
# (9672, 9)

# %%
meta.shape
# Out:
# (2926, 9)

# %%
nevida.shape
# Out:
# (6421, 9)

# %%
tesla.shape
# Out:
# (3545, 9)

# %%
for i in apple.columns:
  print(i)
# Out:
# Date
# Open
# High
# Low
# Close
# Adj Close
# Volume
# Dividends
# Stock Splits
